# %% [markdown]
# # Dataset Audit — Redrob Candidate Discovery
#
# Run `python main.py eda` or execute the cell below.

# %%
import json
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..').resolve()))

from scripts.run_eda import run_eda

report = run_eda(
    Path('../data/raw/candidates.jsonl'),
    Path('../outputs/eda_report.json'),
)
print(json.dumps(report, indent=2))
